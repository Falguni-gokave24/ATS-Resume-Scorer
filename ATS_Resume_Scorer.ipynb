# %%
# !pip install scikit-learn flask nltk pdfplumber
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 43.6/43.6 kB 1.9 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 67.8/67.8 kB 3.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 60.0/60.0 kB 1.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.6/5.6 MB 39.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.0/3.0 MB 67.0 MB/s eta 0:00:00
# ...

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity

def ats_score(resume_text, jd_text):
    vectorizer = TfidfVectorizer(stop_words="english")
    vectors = vectorizer.fit_transform([resume_text, jd_text])
    score = cosine_similarity(vectors[0], vectors[1])[0][0]
    return round(score * 100, 2)

def missing_skills(resume_text, skills):
    resume_text = resume_text.lower()
    return [skill for skill in skills if skill.lower() not in resume_text]

# %%
resume_text = """
I have experience in Python, data analysis, pandas, and machine learning.
"""

job_description = """
Looking for Python developer with ML, SQL, Flask experience.
"""

skills = ["Python", "Machine Learning", "SQL", "Flask"]

print("ATS Score:", ats_score(resume_text, job_description))
print("Missing Skills:", missing_skills(resume_text, skills))
# Out:
# ATS Score: 16.84
# Missing Skills: ['SQL', 'Flask']

# %%
from flask import Flask, request, jsonify

app = Flask(__name__)

@app.route("/score", methods=["POST"])
def score():
    data = request.json
    score = ats_score(data["resume"], data["jd"])
    missing = missing_skills(data["resume"], data["skills"])
    return jsonify({
        "ATS_Score": score,
        "Missing_Skills": missing
    })

app
# Out:
# <Flask '__main__'>
